# %%
import joblib

local_model = joblib.load("my_model.joblib")

house_value =local_model.predict([
    [8.3014, 21.0, 6.23813708, 3.9,
     3.9, 3.9, 2.10984183, 37.86]
])

print("Predicted house value:", house_value)
# Out:
# Predicted house value: [1.77362586]
