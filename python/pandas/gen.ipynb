# %%
print("hello world")
# Out:
# hello world

# %%
import pandas as pd

# %%
s = pd.Series([1, 3, 5, 7, 6, 8])

# %%
s
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    6
# 5    8
# dtype: int64

# %%
s = pd.Series([1, 3, 5, 7, 6, 8], index=['a', 'b', 'c', 'd', 'e', 'f'])
s
# Out:
# a    1
# b    3
# c    5
# d    7
# e    6
# f    8
# dtype: int64

# %%
df=pd.DataFrame({"name":["anuj","kafi","anmol"],"age":[23,24,25]})
df
# Out:
#     name  age
# 0   anuj   23
# 1   kafi   24
# 2  anmol   25

# %%
df=pd.read_csv("graduation_rate (2).csv")
df
# Out:
#      ACT composite score  SAT total score parental level of education  \
# 0                     22             1625                 high school
# 1                     29             2090          associate's degree
# 2                     30             2188           bachelor's degree
# 3                     33             2151          associate's degree
# 4                     29             2050          associate's degree
# ..                   ...              ...                         ...
# 995                   32             2234                some college
# 996                   27             1930                some college
# 997                   32             2117          associate's degree
# 998                   32             2034            some high school
# 999                   34             2268           bachelor's degree
#
#      parental income  high school gpa  college gpa  years to graduate
# ...

# %%
df.tail()
# Out:
#      ACT composite score  SAT total score parental level of education  \
# 995                   32             2234                some college
# 996                   27             1930                some college
# 997                   32             2117          associate's degree
# 998                   32             2034            some high school
# 999                   34             2268           bachelor's degree
#
#      parental income  high school gpa  college gpa  years to graduate
# 995            30658              4.0          3.0                 10
# 996            59443              3.6          3.2                  4
# 997            94415              4.0          3.8                  4
# 998            31713              3.9          3.2                  8
# 999            93832              4.0          3.8                  6

# %%
print(df.memory_usage(deep=True).sum())
# Out:
# 70564

# %%
df[["parental income", "parental level of education"]]
# Out:
#      parental income parental level of education
# 0              40999                 high school
# 1              75817          associate's degree
# 2              82888           bachelor's degree
# 3              93518          associate's degree
# 4              79153          associate's degree
# ..               ...                         ...
# 995            30658                some college
# 996            59443                some college
# 997            94415          associate's degree
# 998            31713            some high school
# 999            93832           bachelor's degree
#
# [1000 rows x 2 columns]

# %%
df.dropna()
# Out:
#      ACT composite score  SAT total score parental level of education  \
# 0                     22             1625                 high school
# 1                     29             2090          associate's degree
# 2                     30             2188           bachelor's degree
# 3                     33             2151          associate's degree
# 4                     29             2050          associate's degree
# ..                   ...              ...                         ...
# 995                   32             2234                some college
# 996                   27             1930                some college
# 997                   32             2117          associate's degree
# 998                   32             2034            some high school
# 999                   34             2268           bachelor's degree
#
#      parental income  high school gpa  college gpa  years to graduate
# ...

# %%
df2=pd.read_csv("graduation_rate (2).csv")
df.fillna(0, inplace=True)
# Out:
#      ACT composite score  SAT total score parental level of education  \
# 0                     22             1625                 high school
# 1                     29             2090          associate's degree
# 2                     30             2188           bachelor's degree
# 3                     33             2151          associate's degree
# 4                     29             2050          associate's degree
# ..                   ...              ...                         ...
# 995                   32             2234                some college
# 996                   27             1930                some college
# 997                   32             2117          associate's degree
# 998                   32             2034            some high school
# 999                   34             2268           bachelor's degree
#
#      parental income  high school gpa  college gpa  years to graduate
# ...

# %%
df.rename(columns={"parental income":"p.i"})
# Out:
#      ACT composite score  SAT total score parental level of education    p.i  \
# 0                     22             1625                 high school  40999
# 1                     29             2090          associate's degree  75817
# 2                     30             2188           bachelor's degree  82888
# 3                     33             2151          associate's degree  93518
# 4                     29             2050          associate's degree  79153
# ..                   ...              ...                         ...    ...
# 995                   32             2234                some college  30658
# 996                   27             1930                some college  59443
# 997                   32             2117          associate's degree  94415
# 998                   32             2034            some high school  31713
# 999                   34             2268           bachelor's degree  93832
#
# ...

# %%
df
# Out:
#      ACT composite score  SAT total score parental level of education  \
# 0                     22             1625                 high school
# 1                     29             2090          associate's degree
# 2                     30             2188           bachelor's degree
# 3                     33             2151          associate's degree
# 4                     29             2050          associate's degree
# ..                   ...              ...                         ...
# 995                   32             2234                some college
# 996                   27             1930                some college
# 997                   32             2117          associate's degree
# 998                   32             2034            some high school
# 999                   34             2268           bachelor's degree
#
#      parental income  high school gpa  college gpa  years to graduate
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      ACT composite score  SAT total score parental level of education  \
# 0                     22             1625                 high school
# 1                     29             2090          associate's degree
# 2                     30             2188           bachelor's degree
# 3                     33             2151          associate's degree
# 4                     29             2050          associate's degree
# ..                   ...              ...                         ...
# 995                   32             2234                some college
# 996                   27             1930                some college
# 997                   32             2117          associate's degree
# 998                   32             2034            some high school
# 999                   34             2268           bachelor's degree
#
#      parental income  high school gpa  college gpa  years to graduate
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ACT composite score          1000 non-null   int64
#  1   SAT total score              1000 non-null   int64
#  2   parental level of education  1000 non-null   str
#  3   parental income              1000 non-null   int64
#  4   high school gpa              1000 non-null   float64
#  5   college gpa                  1000 non-null   float64
#  6   years to graduate            1000 non-null   int64
# dtypes: float64(2), int64(4), str(1)
# memory usage: 68.9 KB

# %%
df['parental income']=df['parental income'].astype('float64')
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ACT composite score          1000 non-null   int64
#  1   SAT total score              1000 non-null   int64
#  2   parental level of education  1000 non-null   str
#  3   parental income              1000 non-null   float64
#  4   high school gpa              1000 non-null   float64
#  5   college gpa                  1000 non-null   float64
#  6   years to graduate            1000 non-null   int64
# dtypes: float64(3), int64(3), str(1)
# memory usage: 68.9 KB

# %%
len(df)
# Out:
# 1000

# %%
df["zeros"]=[0 for i in range(len(df))]
df
# Out:
#      ACT composite score  SAT total score parental level of education  \
# 0                     22             1625                 high school
# 1                     29             2090          associate's degree
# 2                     30             2188           bachelor's degree
# 3                     33             2151          associate's degree
# 4                     29             2050          associate's degree
# ..                   ...              ...                         ...
# 995                   32             2234                some college
# 996                   27             1930                some college
# 997                   32             2117          associate's degree
# 998                   32             2034            some high school
# 999                   34             2268           bachelor's degree
#
#      parental income  high school gpa  college gpa  years to graduate  zeros
# ...

# %%
def fx(a):
    return a+a
df["zeros+1"]=df["years to graduate"].apply(fx)
df
# Out:
#      ACT composite score  SAT total score parental level of education  \
# 0                     22             1625                 high school
# 1                     29             2090          associate's degree
# 2                     30             2188           bachelor's degree
# 3                     33             2151          associate's degree
# 4                     29             2050          associate's degree
# ..                   ...              ...                         ...
# 995                   32             2234                some college
# 996                   27             1930                some college
# 997                   32             2117          associate's degree
# 998                   32             2034            some high school
# 999                   34             2268           bachelor's degree
#
#      parental income  high school gpa  college gpa  years to graduate  zeros  \
# ...

# %%
df.to_csv("graduation_rate (2).csv", index=False)

# %%
df1=pd.DataFrame({"name":["anuj","kafi","anmol"],"age":[23,24,25]})
df1
# Out:
#     name  age
# 0   anuj   23
# 1   kafi   24
# 2  anmol   25

# %%
df2=pd.DataFrame({"name":["anuj","kafi","anmol"],"marks":[23,24,25]})
df2
# Out:
#     name  marks
# 0   anuj     23
# 1   kafi     24
# 2  anmol     25

# %%
df3=pd.merge(df1,df2,on="name")
df3
# Out:
#     name  age  marks
# 0   anuj   23     23
# 1   kafi   24     24
# 2  anmol   25     25
